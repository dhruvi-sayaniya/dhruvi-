# %%
import pandas as pd
data = pd.read_csv('ecommerce_customer_behavior_dataset.csv')
data.head(10)
# Out:
#      Order_ID Customer_ID      Date  Age  Gender      City Product_Category  \
# 0  ORD_001337  CUST_01337  1/1/2023   27  Female     Bursa             Toys
# 1  ORD_004885  CUST_04885  1/1/2023   42    Male     Konya             Toys
# 2  ORD_004507  CUST_04507  1/1/2023   43  Female    Ankara             Food
# 3  ORD_000645  CUST_00645  1/1/2023   32    Male  Istanbul      Electronics
# 4  ORD_000690  CUST_00690  1/1/2023   40  Female  Istanbul           Sports
# 5  ORD_000223  CUST_00223  1/1/2023   43  Female  Istanbul           Beauty
# 6  ORD_002506  CUST_02506  1/1/2023   25  Female     Izmir      Electronics
# 7  ORD_004540  CUST_04540  1/1/2023   44    Male     Konya             Food
# 8  ORD_001808  CUST_01808  1/2/2023   41    Male  Istanbul          Fashion
# 9  ORD_003413  CUST_03413  1/2/2023   58    Male  Istanbul           Sports
#
#    Unit_Price  Quantity  Discount_Amount  Total_Amount    Payment_Method  \
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of         Order_ID Customer_ID       Date  Age  Gender      City  \
# 0     ORD_001337  CUST_01337   1/1/2023   27  Female     Bursa
# 1     ORD_004885  CUST_04885   1/1/2023   42    Male     Konya
# 2     ORD_004507  CUST_04507   1/1/2023   43  Female    Ankara
# 3     ORD_000645  CUST_00645   1/1/2023   32    Male  Istanbul
# 4     ORD_000690  CUST_00690   1/1/2023   40  Female  Istanbul
# ...          ...         ...        ...  ...     ...       ...
# 4995  ORD_001048  CUST_01048  3/26/2024   18  Female     Izmir
# 4996  ORD_001051  CUST_01051  3/26/2024   27    Male     Adana
# 4997  ORD_003543  CUST_03543  3/26/2024   45  Female   Antalya
# 4998  ORD_004443  CUST_04443  3/26/2024   41  Female  Istanbul
# 4999  ORD_000902  CUST_00902  3/26/2024   30  Female     Konya
#
#      Product_Category  Unit_Price  Quantity  Discount_Amount  Total_Amount  \
# 0                Toys       54.28         1             0.00         54.28
# ...

# %%
data.tail()
# Out:
#         Order_ID Customer_ID       Date  Age  Gender      City  \
# 4995  ORD_001048  CUST_01048  3/26/2024   18  Female     Izmir
# 4996  ORD_001051  CUST_01051  3/26/2024   27    Male     Adana
# 4997  ORD_003543  CUST_03543  3/26/2024   45  Female   Antalya
# 4998  ORD_004443  CUST_04443  3/26/2024   41  Female  Istanbul
# 4999  ORD_000902  CUST_00902  3/26/2024   30  Female     Konya
#
#      Product_Category  Unit_Price  Quantity  Discount_Amount  Total_Amount  \
# 4995           Beauty      130.35         1            27.30        103.05
# 4996           Beauty       71.55         1             0.00         71.55
# 4997             Food       39.38         1             5.27         34.11
# 4998          Fashion      171.19         1             0.00        171.19
# 4999            Books       84.30         4            21.72        315.48
#
#       Payment_Method Device_Type  Session_Duration_Minutes  Pages_Viewed  \
# ...

# %%
import pandas as pd
df = pd.read_csv('ecommerce_customer_behavior_dataset.csv')
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
import pandas as pd
df = pd.read_csv("ecommerce_customer_behavior_dataset.csv")
print(df.isnull().sum())
# Out:
# Order_ID                    0
# Customer_ID                 0
# Date                        0
# Age                         0
# Gender                      0
# City                        0
# Product_Category            0
# Unit_Price                  0
# Quantity                    0
# Discount_Amount             0
# Total_Amount                0
# Payment_Method              0
# Device_Type                 0
# Session_Duration_Minutes    0
# Pages_Viewed                0
# Is_Returning_Customer       0
# Delivery_Time_Days          0
# Customer_Rating             0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
print(df.describe())
# Out:
#                Age   Unit_Price     Quantity  Discount_Amount  Total_Amount  \
# count  5000.000000  5000.000000  5000.000000      5000.000000   5000.000000
# mean     35.032600   455.834120     2.220000        24.852804    983.108914
# std      11.080546   712.477209     1.398711        88.385124   1898.978528
# min      18.000000     5.180000     1.000000         0.000000      7.870000
# 25%      27.000000    76.587500     1.000000         0.000000    122.517500
# 50%      35.000000   182.950000     2.000000         0.000000    337.910000
# 75%      42.000000   513.930000     3.000000         8.760000    979.695000
# max      75.000000  7159.450000     5.000000      1525.550000  22023.900000
#
#        Session_Duration_Minutes  Pages_Viewed  Delivery_Time_Days  \
# count                5000.00000    5000.00000         5000.000000
# mean                   14.57340       8.98420            6.497000
# std                     8.66575       2.80434            3.464966
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
plt.figure(figsize=(8,5))
sns.barplot(x="Order_ID",y="Total_Amount",data=df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
plt.figure(figsize=(8,6))
plt.plot(df['Gender'],df['Age'],marker='s')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
plt.figure(figsize=(8,6))
sns.scatterplot(x='Order_ID',y='Total_Amount',data=df)
plt.title('Order_ID vs Total_Amount')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
plt.figure(figsize=(8,6))
plt.hist(df['Age'],bins=10,color='skyblue',edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
corr=df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title('correlation heatmap')
plt.show()

# %%
import pandas as pd
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
print(df.shape)
# Out:
# (5000, 18)

# %%
import pandas as pd
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
print(df['Total_Amount'].mean())
print(df['Total_Amount'].max())
print(df['Total_Amount'].min())
# Out:
# 983.108914
# 22023.9
# 7.87

# %%
import pandas as pd
df= pd.read_csv("ecommerce_customer_behavior_dataset.csv")
grouped=df.groupby('Product_Category')['Total_Amount'].sum()
print(grouped)
# Out:
# Product_Category
# Beauty            156584.74
# Books              72744.52
# Electronics      2328806.81
# Fashion           375214.93
# Food               96138.67
# Home & Garden     908348.86
# Sports            754563.56
# Toys              223142.48
# Name: Total_Amount, dtype: float64

# %%
import pandas as pd 
df=pd.read_csv("ecommerce_customer_behavior_dataset.csv")
filtered=df[df['Total_Amount']>500]
print(filtered)
# Out:
#         Order_ID Customer_ID       Date  Age  Gender      City  \
# 3     ORD_000645  CUST_00645   1/1/2023   32    Male  Istanbul
# 4     ORD_000690  CUST_00690   1/1/2023   40  Female  Istanbul
# 6     ORD_002506  CUST_02506   1/1/2023   25  Female     Izmir
# 8     ORD_001808  CUST_01808   1/2/2023   41    Male  Istanbul
# 9     ORD_003413  CUST_03413   1/2/2023   58    Male  Istanbul
# ...          ...         ...        ...  ...     ...       ...
# 4980  ORD_004882  CUST_04882  3/25/2024   51  Female     Adana
# 4983  ORD_000621  CUST_00621  3/25/2024   25  Female   Antalya
# 4985  ORD_002793  CUST_02793  3/25/2024   30  Female   Antalya
# 4986  ORD_003210  CUST_03210  3/25/2024   40    Male    Ankara
# 4987  ORD_000230  CUST_00230  3/25/2024   43    Male    Ankara
#
#      Product_Category  Unit_Price  Quantity  Discount_Amount  Total_Amount  \
# 3         Electronics      804.06         1           229.28        574.78
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.metrics import classification_report
from sklearn.linear_model import Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
data=pd.read_csv('ecommerce_customer_behavior_dataset.csv')
print(data.head())
x=data[['Quantity','Total_Amount','Age']]
y=data['Discount_Amount']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
Scaler_X = StandardScaler()
Scaler_y = StandardScaler()
X_train_Scaled = Scaler_X.fit_transform(x_train)
X_test_Scaled = Scaler_X.transform(x_test)
y_train_Scaled = Scaler_y.fit_transform(y_train.values.reshape(-1,1)).flatten()                
model= LinearRegression()
# Out:
#      Order_ID Customer_ID      Date  Age  Gender      City Product_Category  \
# 0  ORD_001337  CUST_01337  1/1/2023   27  Female     Bursa             Toys
# 1  ORD_004885  CUST_04885  1/1/2023   42    Male     Konya             Toys
# 2  ORD_004507  CUST_04507  1/1/2023   43  Female    Ankara             Food
# 3  ORD_000645  CUST_00645  1/1/2023   32    Male  Istanbul      Electronics
# 4  ORD_000690  CUST_00690  1/1/2023   40  Female  Istanbul           Sports
#
#    Unit_Price  Quantity  Discount_Amount  Total_Amount    Payment_Method  \
# 0       54.28         1             0.00         54.28        Debit Card
# 1      244.90         1             0.00        244.90       Credit Card
# 2       48.15         5             0.00        240.75       Credit Card
# 3      804.06         1           229.28        574.78       Credit Card
# 4      755.61         5             0.00       3778.05  Cash on Delivery
#
# ...

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
df=pd.read_csv('ecommerce_customer_behavior_dataset.csv')
df.columns=df.columns.str.strip()
print("columns in the datasets:",df.columns)
y_true = df['Delivery_Time_Days']
y_pred = df['Customer_Rating']
accuracy = accuracy_score(y_true, y_pred)
print("model accuracy:", accuracy)
# Out:
# columns in the datasets: Index(['Order_ID', 'Customer_ID', 'Date', 'Age', 'Gender', 'City',
#        'Product_Category', 'Unit_Price', 'Quantity', 'Discount_Amount',
#        'Total_Amount', 'Payment_Method', 'Device_Type',
#        'Session_Duration_Minutes', 'Pages_Viewed', 'Is_Returning_Customer',
#        'Delivery_Time_Days', 'Customer_Rating'],
#       dtype='object')
# model accuracy: 0.1122

# %%
x=data[['Quantity','Total_Amount','Age']]
y=data['Discount_Amount']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
Scaler_X = StandardScaler()
Scaler_y = StandardScaler()
X_train_Scaled = Scaler_X.fit_transform(x_train)
X_test_Scaled = Scaler_X.transform(x_test)
y_train_Scaled = Scaler_y.fit_transform(y_train.values.reshape(-1,1)).flatten()
models = {
   'Linear Regression': LinearRegression(),
   'Ridge':Ridge(),
   'Lasso':Lasso(),
   'Decision Tree': DecisionTreeRegressor(random_state = 42,max_depth = 10),
   'Random forest': RandomForestRegressor(n_estimators=100,random_state=42,max_depth=10)
} 

result ={}
for name,model in models.items():
    model.fit(X_train_Scaled, y_train_scaled)
    y_pred_scaled = model.predict(X_test_scaled)
    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1,1)).flatten()
    result[name] = {
        "R2": r2_score(y_test,y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred))
    }
result_df = pd.DataFrame(results).T
print(results_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 19
#      17 result ={}
#      18 for name,model in models.items():
# ---> 19     model.fit(X_train_Scaled, y_train_scaled)
#      20     y_pred_scaled = model.predict(X_test_scaled)
#      21     y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1,1)).flatten()
#
# NameError: name 'y_train_scaled' is not defined

# %%
x=data[['Quantity','Total_Amount','Age']]
y=data['Discount_Amount']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
Scaler_X = StandardScaler()
Scaler_y = StandardScaler()
X_train_Scaled = Scaler_X.fit_transform(x_train)
X_test_Scaled = Scaler_X.transform(x_test)
y_train_Scaled = Scaler_y.fit_transform(y_train.values.reshape(-1,1)).flatten()
models = {
   'Linear Regression': LinearRegression(),
   'Ridge':Ridge(),
   'Lasso':Lasso(),
   'Decision Tree': DecisionTreeRegressor(random_state = 42,max_depth = 10),
   'Random forest': RandomForestRegressor(n_estimators=100,random_state=42,max_depth=10)
} 

result ={}
for name,model in models.items():
    model.fit(X_train_Scaled,y_train_Scaled)
    y_pred_scaled = model.predict(X_test_Scaled)
    y_pred = Scaler_y.inverse_transform(y_pred_scaled.reshape(-1,1)).flatten()
    result[name] = {
        "R2": r2_score(y_test,y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred))
    }
result_df = pd.DataFrame(result).T
print(result_df)
# Out:
#                          R2       RMSE
# Linear Regression  0.066239  62.500887
# Ridge              0.066271  62.499812
# Lasso             -0.003250  64.784763
# Decision Tree     -0.839360  87.720590
# Random forest     -0.014307  65.140770

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('ecommerce_customer_behavior_dataset.csv')
plt.figure(figsize=(8,6))
sns.histplot(df['Total_Amount'],bins=30, kde=True, color='blue')
plt.title('ecommerce_customer_behavior_dataset.csv')
plt.xlabel('Total_Amount')
plt.ylabel('Product_Category')
plt.show()

# %%
# !pip install streamlit

# %%
# !streamlit hello
